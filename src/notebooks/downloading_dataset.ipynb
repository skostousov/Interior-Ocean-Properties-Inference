# %%
from utils.dataset import download_dataset
from utils.config import DATA_DIR, RAW_CONFIG

# %%
download_dataset('skostousov', DATA_DIR, (2021, 6, 24), (2021, 6, 30), (-200, -100), (-20, 60))
# Out:
# Copernicus Marine password:
# ---------------------------------------------------------------------------
# InvalidUsernameOrPassword                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 download_dataset('skostousov', DATA_DIR, (2021, 6, 24), (2021, 6, 30), (-200, -100), (-20, 60))
#
# File ~/SynologyDrive/OceanPropInfSatImg/src/utils/dataset.py:24, in download_dataset(username, output_dir, start_day, end_day, longitude, latitude)
#      22     start_datetime = f"{start_date}T00:00:00"
#      23     end_datetime = f"{end_date}T00:00:00"
# ---> 24     copernicusmarine.subset(
#      25     dataset_id="cmems_mod_glo_phy_my_0.083deg_P1D-m",
#      26     username=username,
#      27     dataset_version="202311",
#      28     variables=FEATURES,
#      29     minimum_longitude=min(longitude),
#      30     maximum_longitude=max(longitude),
#      31     minimum_latitude=min(latitude),
#      32     maximum_latitude=max(latitude),
# ...
