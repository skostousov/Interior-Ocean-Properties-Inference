# %%
from utils.dataset import download_dataset
from utils.config import DATA_DIR, SAVED_MODELS_DIR, RAW_CONFIG
import torch
from models.Unet import UNet
from utils.dataset import GLORYSDS

# %%
download_dataset(RAW_CONFIG['copernicusmarine']["USERNAME"], output_dir=DATA_DIR, start_day=(1993, 10, 11), end_day=(1993, 10, 12), longitude=(-190, -120), latitude=(30, 60))
# Out:
# Copernicus Marine password:
# INFO - 2025-05-15T20:24:55Z - Selected dataset version: "202311"
# INFO - 2025-05-15T20:24:55Z - Selected dataset part: "default"
# INFO - 2025-05-15T20:25:09Z - Starting download. Please wait...
#   0%|          | 0/21 [00:00<?, ?it/s]
# INFO - 2025-05-15T20:25:21Z - Successfully downloaded to /mnt/c/Users/samue/SynologyDrive/OceanPropInfSatImg/data/lat:30-60_long:-190--120_date:1993-10-11-1993-10-12.nc
